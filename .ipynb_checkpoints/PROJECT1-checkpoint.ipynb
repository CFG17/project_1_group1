# %%
! pip install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Collecting pandas>=0.20.0
#   Downloading pandas-1.1.3-cp38-cp38-win_amd64.whl (8.9 MB)
# Requirement already satisfied: scipy>=0.18 in c:\users\antho\anaconda3\envs\pydata\lib\site-packages (from plotly.express) (1.5.0)
# Collecting plotly>=4.1.0
#   Downloading plotly-4.12.0-py2.py3-none-any.whl (13.1 MB)
# Collecting statsmodels>=0.9.0
#   Downloading statsmodels-0.12.0-cp38-none-win_amd64.whl (9.2 MB)
# Requirement already satisfied: numpy>=1.11 in c:\users\antho\anaconda3\envs\pydata\lib\site-packages (from plotly.express) (1.19.1)
# Collecting patsy>=0.5
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\antho\anaconda3\envs\pydata\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.8.1)
# Requirement already satisfied: six in c:\users\antho\anaconda3\envs\pydata\lib\site-packages (from plotly>=4.1.0->plotly.express) (1.15.0)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11434 sha256=48ec81fc23a8105726897ff3a30bb34507960d819da87bdcd79f6a4014bf94f8
#   Stored in directory: c:\users\antho\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: pytz, pandas, retrying, plotly, patsy, statsmodels, plotly.express
# Successfully installed pandas-1.1.3 patsy-0.5.1 plotly-4.12.0 plotly.express pytz-2020.1 retrying-1.3.3 statsmodels-0.12.0

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sts
import numpy as np
from scipy.stats import linregress
import seaborn as sns
import datetime as dt
import plotly as plotly
#import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-a41e6fd4cabc> in <module>
#       1 # Dependencies
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplot as plt
#       4 import scipy.stats as sts
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
 #Read in the CSV set
main_data = pd.read_csv('googleplaystore.csv')
main_data.head()
# Out:
#    Rating                                                App        Category  \
# 0     4.1     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1     3.9                                Coloring book moana  ART_AND_DESIGN
# 2     4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3     4.5                              Sketch - Draw & Paint  ART_AND_DESIGN
# 4     4.3              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
#    Reviews  Size     Installs  Type Price Content Rating  \
# 0      159   19M      10,000+  Free     0       Everyone
# 1      967   14M     500,000+  Free     0       Everyone
# 2    87510  8.7M   5,000,000+  Free     0       Everyone
# 3   215644   25M  50,000,000+  Free     0           Teen
# 4      967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver
# 0               Art & Design    07-Jan-18               1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play    15-Jan-18               2.0.0  4.0.3 and up
# 2               Art & Design    01-Aug-18               1.2.4  4.0.3 and up
# 3               Art & Design    08-Jun-18  Varies with device    4.2 and up
# 4    Art & Design;Creativity    20-Jun-18                 1.1    4.4 and up

# %%
#Evaluate count of ratings
main_data.count()
# Out:
# Rating             9366
# App               10840
# Category          10840
# Reviews           10840
# Size              10840
# Installs          10840
# Type              10839
# Price             10840
# Content Rating    10840
# Genres            10840
# Last Updated      10840
# Current Ver       10832
# Android Ver       10838
# dtype: int64

# %%
#drop rating with zero value
updated_df = main_data.dropna()

#Evaluate # of ratings 
updated_df.count()
# Out:
# Rating            9360
# App               9360
# Category          9360
# Reviews           9360
# Size              9360
# Installs          9360
# Type              9360
# Price             9360
# Content Rating    9360
# Genres            9360
# Last Updated      9360
# Current Ver       9360
# Android Ver       9360
# dtype: int64

# %%
# Cleaned data to show columns
cleaned_df = updated_df[['Rating','App','Category','Reviews','Type','Installs','Last Updated']]
cleaned_df
# Out:
#        Rating                                                App  \
# 0         4.1     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         3.9                                Coloring book moana
# 2         4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         4.5                              Sketch - Draw & Paint
# 4         4.3              Pixel Draw - Number Art Coloring Book
# ...       ...                                                ...
# 10833     4.0                                      FR Calculator
# 10835     4.5                                   Sya9a Maroc - FR
# 10836     5.0                   Fr. Mike Schmitz Audio Teachings
# 10838     4.5                      The SCP Foundation DB fr nn5n
# 10839     4.5      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Reviews  Type     Installs Last Updated
# 0           ART_AND_DESIGN      159  Free      10,000+    07-Jan-18
# 1           ART_AND_DESIGN      967  Free     500,000+    15-Jan-18
# 2           ART_AND_DESIGN    87510  Free   5,000,000+    01-Aug-18
# 3           ART_AND_DESIGN   215644  Free  50,000,000+    08-Jun-18
# 4           ART_AND_DESIGN      967  Free     100,000+    20-Jun-18
# ...                    ...      ...   ...          ...          ...
# 10833               FAMILY        7  Free         500+    18-Jun-17
# 10835               FAMILY       38  Free       5,000+    25-Jul-17
# 10836               FAMILY        4  Free         100+    06-Jul-18
# 10838  BOOKS_AND_REFERENCE      114  Free       1,000+    19-Jan-15
# 10839            LIFESTYLE   398307  Free  10,000,000+    25-Jul-18
#
# [9360 rows x 7 columns]

# %%
#looking for the updated unique values
n = cleaned_df.nunique(axis=0)
n
# Out:
# Rating            39
# App             8190
# Category          33
# Reviews         5990
# Type               2
# Installs          19
# Last Updated    1299
# dtype: int64

# %%
#State the number of rows and columns
cleaned_df.shape
# Out:
# (9360, 7)

# %%
cleaned_df = cleaned_df.drop_duplicates(subset="App")
cleaned_df
# Out:
#        Rating                                                App  \
# 0         4.1     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         3.9                                Coloring book moana
# 2         4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         4.5                              Sketch - Draw & Paint
# 4         4.3              Pixel Draw - Number Art Coloring Book
# ...       ...                                                ...
# 10833     4.0                                      FR Calculator
# 10835     4.5                                   Sya9a Maroc - FR
# 10836     5.0                   Fr. Mike Schmitz Audio Teachings
# 10838     4.5                      The SCP Foundation DB fr nn5n
# 10839     4.5      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Reviews  Type     Installs Last Updated
# 0           ART_AND_DESIGN      159  Free      10,000+    07-Jan-18
# 1           ART_AND_DESIGN      967  Free     500,000+    15-Jan-18
# 2           ART_AND_DESIGN    87510  Free   5,000,000+    01-Aug-18
# 3           ART_AND_DESIGN   215644  Free  50,000,000+    08-Jun-18
# 4           ART_AND_DESIGN      967  Free     100,000+    20-Jun-18
# ...                    ...      ...   ...          ...          ...
# 10833               FAMILY        7  Free         500+    18-Jun-17
# 10835               FAMILY       38  Free       5,000+    25-Jul-17
# 10836               FAMILY        4  Free         100+    06-Jul-18
# 10838  BOOKS_AND_REFERENCE      114  Free       1,000+    19-Jan-15
# 10839            LIFESTYLE   398307  Free  10,000,000+    25-Jul-18
#
# [8190 rows x 7 columns]

# %%
#Convert Install to numberic          #.loc[row_indexer,col_indexer] = value
newInstalls = []
for row in cleaned_df.Installs:
    row = row[:-1]
    newRow = row.replace(",", "")
    newInstalls.append(float(newRow))
cleaned_df.Installs = newInstalls
cleaned_df.Installs.head()
# Out:
# C:\Users\Antho\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# 0       10000.0
# 1      500000.0
# 2     5000000.0
# 3    50000000.0
# 4      100000.0
# Name: Installs, dtype: float64

# %%
# check the updated installs column
cleaned_df.Installs
# Out:
# 0           10000.0
# 1          500000.0
# 2         5000000.0
# 3        50000000.0
# 4          100000.0
#             ...
# 10833         500.0
# 10835        5000.0
# 10836         100.0
# 10838        1000.0
# 10839    10000000.0
# Name: Installs, Length: 8190, dtype: float64

# %%
 #CATEGORIES VS. RATINGS
#cat_df =cleaned_df[['Category','Rating']]

# %%
#Processing the category column
cleaned_df['Category'].value_counts(dropna=False)
# Out:
# FAMILY                 1607
# GAME                    912
# TOOLS                   717
# FINANCE                 302
# LIFESTYLE               301
# PRODUCTIVITY            301
# PERSONALIZATION         296
# MEDICAL                 290
# PHOTOGRAPHY             263
# BUSINESS                263
# SPORTS                  260
# COMMUNICATION           256
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# MAPS_AND_NAVIGATION     118
# EDUCATION               118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       63
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           60
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# Name: Category, dtype: int64

# %%
cleaned_df.dtypes
# Out:
# Rating          float64
# App              object
# Category         object
# Reviews           int64
# Type             object
# Installs        float64
# Last Updated     object
# dtype: object

# %%
#cleaned_df=pd.to_datetime(['Last Updated'], format='%d-%m-%Y ')
#cleand_df

#cleaned_df['date'] = cleaned_df['Last Updated'].dt.strftime('%m/%d/%Y')
updated_df['Last Updated'] = pd.to_datetime(updated_df['Last Updated'])
updated_df
# Out:
# <ipython-input-30-3a6841b79238>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   updated_df['Last Updated'] = pd.to_datetime(updated_df['Last Updated'])
#        Rating                                                App  \
# 0         4.1     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         3.9                                Coloring book moana
# 2         4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         4.5                              Sketch - Draw & Paint
# 4         4.3              Pixel Draw - Number Art Coloring Book
# ...       ...                                                ...
# 10833     4.0                                      FR Calculator
# 10835     4.5                                   Sya9a Maroc - FR
# 10836     5.0                   Fr. Mike Schmitz Audio Teachings
# 10838     4.5                      The SCP Foundation DB fr nn5n
# 10839     4.5      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Reviews                Size     Installs  Type  \
# 0           ART_AND_DESIGN      159                 19M      10,000+  Free
# 1           ART_AND_DESIGN      967                 14M     500,000+  Free
# 2           ART_AND_DESIGN    87510                8.7M   5,000,000+  Free
# 3           ART_AND_DESIGN   215644                 25M  50,000,000+  Free
# 4           ART_AND_DESIGN      967                2.8M     100,000+  Free
# ...                    ...      ...                 ...          ...   ...
# 10833               FAMILY        7                2.6M         500+  Free
# 10835               FAMILY       38                 53M       5,000+  Free
# 10836               FAMILY        4                3.6M         100+  Free
# 10838  BOOKS_AND_REFERENCE      114  Varies with device       1,000+  Free
# 10839            LIFESTYLE   398307                 19M  10,000,000+  Free
#
#       Price Content Rating                     Genres Last Updated  \
# 0         0       Everyone               Art & Design   2018-01-07
# 1         0       Everyone  Art & Design;Pretend Play   2018-01-15
# 2         0       Everyone               Art & Design   2018-08-01
# 3         0           Teen               Art & Design   2018-06-08
# 4         0       Everyone    Art & Design;Creativity   2018-06-20
# ...     ...            ...                        ...          ...
# 10833     0       Everyone                  Education   2017-06-18
# 10835     0       Everyone                  Education   2017-07-25
# 10836     0       Everyone                  Education   2018-07-06
# 10838     0     Mature 17+          Books & Reference   2015-01-19
# 10839     0       Everyone                  Lifestyle   2018-07-25
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# ...                   ...                 ...
# 10833               1.0.0          4.1 and up
# 10835                1.48          4.1 and up
# 10836                   1          4.1 and up
# 10838  Varies with device  Varies with device
# 10839  Varies with device  Varies with device
#
# [9360 rows x 13 columns]

# %%
cleaned_df['Last Updated'] = pd.to_datetime(cleaned_df['Last Updated'])
cleaned_df
# Out:
# <ipython-input-31-6652002cde9e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df['Last Updated'] = pd.to_datetime(cleaned_df['Last Updated'])
#        Rating                                                App  \
# 0         4.1     Photo Editor & Candy Camera & Grid & ScrapBook
# 1         3.9                                Coloring book moana
# 2         4.7  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3         4.5                              Sketch - Draw & Paint
# 4         4.3              Pixel Draw - Number Art Coloring Book
# ...       ...                                                ...
# 10833     4.0                                      FR Calculator
# 10835     4.5                                   Sya9a Maroc - FR
# 10836     5.0                   Fr. Mike Schmitz Audio Teachings
# 10838     4.5                      The SCP Foundation DB fr nn5n
# 10839     4.5      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                   Category  Reviews  Type    Installs Last Updated
# 0           ART_AND_DESIGN      159  Free     10000.0   2018-01-07
# 1           ART_AND_DESIGN      967  Free    500000.0   2018-01-15
# 2           ART_AND_DESIGN    87510  Free   5000000.0   2018-08-01
# 3           ART_AND_DESIGN   215644  Free  50000000.0   2018-06-08
# 4           ART_AND_DESIGN      967  Free    100000.0   2018-06-20
# ...                    ...      ...   ...         ...          ...
# 10833               FAMILY        7  Free       500.0   2017-06-18
# 10835               FAMILY       38  Free      5000.0   2017-07-25
# 10836               FAMILY        4  Free       100.0   2018-07-06
# 10838  BOOKS_AND_REFERENCE      114  Free      1000.0   2015-01-19
# 10839            LIFESTYLE   398307  Free  10000000.0   2018-07-25
#
# [8190 rows x 7 columns]

# %%
#bar chart
category_list = list(cleaned_df['Category'].unique())
category_Rating = []
for i in category_list:
    x = cleaned_df[cleaned_df['Category'] == i]
    if(len(x)!=0):
        Rating = sum(x.Rating)/len(x)
        category_Rating.append(Rating)
    else:
        Rating = sum(x.Category)
        category_Rating.append(Rating)
        
#sorting
data_category_Rating= pd.DataFrame({'Category': category_list,'Rating':category_Rating})
new_index = (data_category_Rating['Rating'].sort_values(ascending=False)).index.values
sorted_data =data_category_Rating.reindex(new_index)

# visualization
plt.figure(figsize=(15,10))
sns.barplot(x=sorted_data['Category'], y=sorted_data['Rating'])
plt.xticks(rotation=80)
plt.ylim(0,5.5)
plt.xlabel("Category")
plt.ylabel("Rating")
plt.title("Category and Rating")
plt.show()

# %%
# # Number of INSTALLS VS. RATINGS   
# install_df = pd.DataFrame(cleaned_df,columns =['Installs','Rating'])
# plt.plot(install_df['Installs'], install_df['Rating'], color='green', marker='o')
# plt.title('Rating Vs Number of Installs', fontsize=14)
# plt.xlabel('Installs', fontsize=14)
# plt.ylabel('Rating', fontsize=14)
# plt.grid(True)
# plt.show()

# %%
import plotly.express as px
# This dataframe has 244 lines, but 4 distinct values for `day`
df = px.data.tips()
fig = px.pie(df, values='tip', names='day')
fig.show()

# %%
# pie_chart = install_df['Category'].unique()
# print pie_chart.sort()
# pie_chart

# %%
# category_list = list(cleaned_df['Category'].unique())
category_review = []
for i in category_list:
    x = cleaned_df[cleaned_df['Category'] == i]
    if(len(x)!=0):
        review = sum(x.Reviews)/len(x)
        category_review.append(review)
    else:
        review = sum(x.Reviews)
        category_review.append(review)
#sorting
data_category_reviews = pd.DataFrame({'category': category_list,'review':category_review})
new_index = (data_category_reviews['review'].sort_values(ascending=False)).index.values
sorted_data =data_category_reviews.reindex(new_index)

# visualization
plt.figure(figsize=(15,10))
plt.bar(x=sorted_data['category'], y=sorted_data['review'])
plt.xticks(rotation=80)
plt.yticks()
plt.xlabel("Category")
plt.ylabel("Reviews")
plt.title("Category and Reviews")
plt.show()

# %%
x_axis = np.arange(0, len(gyms))
tick_locations = []
for x in x_axis:
    tick_locations.append(x)

plt.title("NYC Gym Popularity")
plt.xlabel("Gym Name")
plt.ylabel("Number of Members")

plt.xlim(-0.75, len(gyms)-.25)
plt.ylim(0, max(members) + 5)

plt.bar(x_axis, members, facecolor="red", alpha=0.75, align="center")
plt.xticks(tick_locations, gyms)
plt.show()

# %%
# NUMBER of REVIEWS VS. RATINGS

# review_df =cleaned_df[['Reviews','Rating']]
# review_df

# %%
# # Updated versions vs Ratings ************************** HOW DO WE QUANTIFY THE DATE???
# upver_df =cleaned_df[['Last Updated','Rating']]
# upver_df
